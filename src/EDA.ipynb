# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %%
data_folder = '/home/bartheq/Documents/playground/image_colorization/data/layout_images/'
save_directory = '/home/bartheq/Documents/playground/image_colorization/data/'
os.listdir(data_folder)
# Out:
# ['._image_488.jpg',
#  'image_3731.jpg',
#  'image_1683.jpg',
#  'image_3548.jpg',
#  'image_877.jpg',
#  'image_4754.jpg',
#  'image_1426.jpg',
#  'image_1867.jpg',
#  'image_1730.jpg',
#  'image_5557.jpg',
#  'image_4648.jpg',
#  'image_6024.jpg',
#  'image_1514.jpg',
#  '._image_193.jpg',
#  'image_5555.jpg',
#  'image_5012.jpg',
#  'image_2178.jpg',
#  'image_6014.jpg',
#  'image_1036.jpg',
#  'image_4038.jpg',
#  'image_372.jpg',
#  'image_3029.jpg',
#  'image_6810.jpg',
#  'image_6698.jpg',
#  'image_1601.jpg',
#  '._image_325.jpg',
#  'image_577.jpg',
#  'image_1123.jpg',
#  'image_161.jpg',
#  '._image_141.jpg',
#  'image_5052.jpg',
#  'image_3428.jpg',
#  'image_4489.jpg',
#  'image_3281.jpg',
#  'image_1054.jpg',
#  'image_2647.jpg',
#  'image_671.jpg',
#  'image_2870.jpg',
#  'image_5019.jpg',
#  'image_905.jpg',
#  'image_2550.jpg',
#  'image_1794.jpg',
#  'image_6795.jpg',
#  'image_5647.jpg',
#  'image_6677.jpg',
#  'image_3885.jpg',
#  'image_5606.jpg',
#  'image_2662.jpg',
#  'image_9.jpg',
#  'image_2802.jpg',
#  'image_3075.jpg',
#  'image_3673.jpg',
#  'image_1256.jpg',
#  'image_4330.jpg',
#  'image_1427.jpg',
#  'image_4976.jpg',
#  'image_4891.jpg',
#  'image_2899.jpg',
#  'image_2030.jpg',
#  'image_6171.jpg',
#  'image_495.jpg',
#  'image_2322.jpg',
#  'image_5338.jpg',
#  'image_6611.jpg',
#  'image_760.jpg',
#  '._image_22.jpg',
#  'image_3439.jpg',
#  '._image_345.jpg',
#  'image_3292.jpg',
#  'image_5816.jpg',
#  'image_7108.jpg',
#  'image_7042.jpg',
#  'image_2061.jpg',
#  'image_3973.jpg',
#  'image_99.jpg',
#  'image_4036.jpg',
#  'image_5643.jpg',
#  'image_3936.jpg',
#  'image_5176.jpg',
#  'image_3803.jpg',
#  'image_1772.jpg',
#  'image_5487.jpg',
#  'image_625.jpg',
#  'image_2833.jpg',
#  'image_6199.jpg',
#  'image_3616.jpg',
#  'image_1082.jpg',
#  'image_1694.jpg',
#  'image_1918.jpg',
#  'image_3201.jpg',
#  'image_1877.jpg',
#  'image_1972.jpg',
#  'image_2937.jpg',
#  'image_1060.jpg',
#  'image_1378.jpg',
#  'image_3139.jpg',
#  'image_2641.jpg',
#  'image_3536.jpg',
#  'image_6038.jpg',
#  'image_6625.jpg',
#  'image_5802.jpg',
#  'image_5876.jpg',
#  'image_2570.jpg',
#  'image_1716.jpg',
#  'image_992.jpg',
#  'image_4496.jpg',
#  'image_3931.jpg',
#  'image_3907.jpg',
#  'image_3626.jpg',
#  'image_3062.jpg',
#  'image_5705.jpg',
#  'image_1813.jpg',
#  'image_1447.jpg',
#  'image_4332.jpg',
#  'image_3980.jpg',
#  '._image_216.jpg',
#  'image_166.jpg',
#  'image_4888.jpg',
#  'image_5503.jpg',
#  'image_422.jpg',
#  'image_4939.jpg',
#  'image_2549.jpg',
#  'image_4085.jpg',
#  'image_6197.jpg',
#  'image_5516.jpg',
#  'image_1391.jpg',
#  'image_451.jpg',
#  '._image_203.jpg',
#  'image_4505.jpg',
#  'image_6742.jpg',
#  'image_1127.jpg',
#  'image_1853.jpg',
#  'image_6581.jpg',
#  'image_782.jpg',
#  'image_4069.jpg',
#  'image_2864.jpg',
#  'image_2191.jpg',
#  'image_3734.jpg',
#  'image_2910.jpg',
#  'image_5132.jpg',
#  'image_5029.jpg',
#  '._image_196.jpg',
#  'image_544.jpg',
#  'image_673.jpg',
#  'image_396.jpg',
#  'image_5818.jpg',
#  'image_6369.jpg',
#  'image_6142.jpg',
#  'image_1057.jpg',
#  'image_2957.jpg',
#  'image_5024.jpg',
#  'image_2978.jpg',
#  'image_4204.jpg',
#  'image_1958.jpg',
#  'image_4096.jpg',
#  'image_927.jpg',
#  '._image_413.jpg',
#  'image_73.jpg',
#  'image_2814.jpg',
#  'image_2859.jpg',
#  'image_4693.jpg',
#  'image_3581.jpg',
#  'image_2269.jpg',
#  'image_2880.jpg',
#  'image_5760.jpg',
#  'image_6282.jpg',
#  'image_1214.jpg',
#  'image_775.jpg',
#  'image_3370.jpg',
#  'image_464.jpg',
#  'image_2080.jpg',
#  'image_5691.jpg',
#  'image_2933.jpg',
#  'image_6470.jpg',
#  'image_6982.jpg',
#  'image_591.jpg',
#  'image_7111.jpg',
#  'image_2840.jpg',
#  'image_4101.jpg',
#  'image_581.jpg',
#  'image_5701.jpg',
#  'image_4776.jpg',
#  'image_1175.jpg',
#  'image_6455.jpg',
#  'image_642.jpg',
#  'image_7104.jpg',
#  'image_5461.jpg',
#  'image_3305.jpg',
#  'image_1102.jpg',
#  'image_5748.jpg',
#  'image_6000.jpg',
#  'image_1585.jpg',
#  'image_3762.jpg',
#  'image_1921.jpg',
#  'image_4227.jpg',
#  'image_4189.jpg',
#  'image_4921.jpg',
#  'image_689.jpg',
#  'image_3450.jpg',
#  'image_2362.jpg',
#  'image_1667.jpg',
#  'image_3630.jpg',
#  'image_5608.jpg',
#  'image_5532.jpg',
#  'image_3671.jpg',
#  'image_6863.jpg',
#  'image_5198.jpg',
#  'image_1861.jpg',
#  'image_6471.jpg',
#  'image_5028.jpg',
#  'image_4314.jpg',
#  'image_2470.jpg',
#  'image_4951.jpg',
#  'image_6356.jpg',
#  'image_6426.jpg',
#  '._image_52.jpg',
#  'image_1293.jpg',
#  'image_2698.jpg',
#  'image_3032.jpg',
#  'image_5616.jpg',
#  'image_6118.jpg',
#  'image_6846.jpg',
#  'image_6553.jpg',
#  'image_6359.jpg',
#  'image_5284.jpg',
#  'image_3137.jpg',
#  'image_1912.jpg',
#  'image_6103.jpg',
#  '._image_461.jpg',
#  'image_6964.jpg',
#  'image_5301.jpg',
#  'image_2477.jpg',
#  'image_5311.jpg',
#  'image_4700.jpg',
#  'image_6558.jpg',
#  'image_5640.jpg',
#  'image_1857.jpg',
#  'image_2909.jpg',
#  'image_5280.jpg',
#  'image_5767.jpg',
#  'image_6983.jpg',
#  'image_2858.jpg',
#  'image_5057.jpg',
#  'image_394.jpg',
#  'image_4804.jpg',
#  'image_3507.jpg',
#  'image_1014.jpg',
#  'image_2045.jpg',
#  'image_6745.jpg',
#  'image_4397.jpg',
#  '._image_484.jpg',
#  'image_6085.jpg',
#  'image_6389.jpg',
#  'image_4789.jpg',
#  'image_2111.jpg',
#  'image_1739.jpg',
#  'image_3524.jpg',
#  'image_5629.jpg',
#  'image_6046.jpg',
#  'image_5417.jpg',
#  'image_83.jpg',
#  'image_3534.jpg',
#  'image_1012.jpg',
#  '._image_312.jpg',
#  'image_4716.jpg',
#  'image_2945.jpg',
#  'image_3197.jpg',
#  'image_6488.jpg',
#  'image_5768.jpg',
#  '._image_15.jpg',
#  'image_517.jpg',
#  'image_3537.jpg',
#  'image_654.jpg',
#  'image_3424.jpg',
#  'image_382.jpg',
#  'image_4097.jpg',
#  'image_788.jpg',
#  'image_3334.jpg',
#  'image_6549.jpg',
#  'image_7135.jpg',
#  'image_454.jpg',
#  'image_5309.jpg',
#  'image_5727.jpg',
#  '._image_147.jpg',
#  'image_3763.jpg',
#  'image_6993.jpg',
#  'image_4104.jpg',
#  'image_4111.jpg',
#  'image_2705.jpg',
#  'image_5895.jpg',
#  'image_5903.jpg',
#  'image_1940.jpg',
#  'image_2554.jpg',
#  'image_7136.jpg',
#  'image_5409.jpg',
#  'image_3838.jpg',
#  'image_203.jpg',
#  'image_815.jpg',
#  'image_2181.jpg',
#  'image_3279.jpg',
#  'image_515.jpg',
#  'image_6140.jpg',
#  'image_976.jpg',
#  'image_7071.jpg',
#  'image_913.jpg',
#  'image_3636.jpg',
#  'image_6080.jpg',
#  'image_1669.jpg',
#  'image_5542.jpg',
#  'image_6699.jpg',
#  '._image_392.jpg',
#  'image_3419.jpg',
#  'image_1043.jpg',
#  'image_3682.jpg',
#  'image_3863.jpg',
#  'image_5833.jpg',
#  'image_1031.jpg',
#  '._image_471.jpg',
#  'image_282.jpg',
#  'image_4994.jpg',
#  'image_5605.jpg',
#  '._image_480.jpg',
#  'image_620.jpg',
#  'image_317.jpg',
#  'image_1812.jpg',
#  'image_6020.jpg',
#  'image_6879.jpg',
#  'image_1769.jpg',
#  'image_179.jpg',
#  'image_5821.jpg',
#  'image_4897.jpg',
#  '._image_263.jpg',
#  'image_965.jpg',
#  'image_2035.jpg',
#  'image_2888.jpg',
#  'image_2480.jpg',
#  'image_2276.jpg',
#  'image_6934.jpg',
#  'image_3575.jpg',
#  'image_1886.jpg',
#  'image_4439.jpg',
#  'image_6527.jpg',
#  'image_6127.jpg',
#  'image_4681.jpg',
#  'image_6164.jpg',
#  'image_2432.jpg',
#  '._image_251.jpg',
#  'image_4276.jpg',
#  '._image_162.jpg',
#  'image_5963.jpg',
#  'image_5151.jpg',
#  'image_5397.jpg',
#  'image_6001.jpg',
#  'image_954.jpg',
#  'image_1703.jpg',
#  'image_4098.jpg',
#  'image_701.jpg',
#  'image_1725.jpg',
#  'image_3256.jpg',
#  'image_3500.jpg',
#  'image_1472.jpg',
#  'image_2575.jpg',
#  'image_2153.jpg',
#  '._image_158.jpg',
#  'image_6251.jpg',
#  'image_4435.jpg',
#  '._image_12.jpg',
#  'image_4222.jpg',
#  'image_1774.jpg',
#  'image_1823.jpg',
#  'image_6155.jpg',
#  'image_5424.jpg',
#  'image_2353.jpg',
#  '._image_145.jpg',
#  'image_5193.jpg',
#  'image_1058.jpg',
#  'image_128.jpg',
#  'image_1795.jpg',
#  'image_4941.jpg',
#  'image_5512.jpg',
#  'image_1919.jpg',
#  'image_6826.jpg',
#  'image_3906.jpg',
#  '._image_178.jpg',
#  'image_2168.jpg',
#  'image_1065.jpg',
#  'image_2807.jpg',
#  'image_441.jpg',
#  'image_6686.jpg',
#  'image_140.jpg',
#  'image_5196.jpg',
#  'image_928.jpg',
#  'image_1029.jpg',
#  'image_3166.jpg',
#  'image_2770.jpg',
#  'image_5812.jpg',
#  'image_4984.jpg',
#  'image_6666.jpg',
#  'image_1094.jpg',
#  'image_813.jpg',
#  'image_4362.jpg',
#  'image_5210.jpg',
#  'image_1350.jpg',
#  'image_4925.jpg',
#  'image_3997.jpg',
#  'image_5594.jpg',
#  'image_4458.jpg',
#  'image_6632.jpg',
#  'image_4220.jpg',
#  'image_4507.jpg',
#  'image_3377.jpg',
#  'image_1220.jpg',
#  'image_1200.jpg',
#  'image_6624.jpg',
#  'image_6812.jpg',
#  '._image_133.jpg',
#  'image_6852.jpg',
#  'image_6885.jpg',
#  'image_2734.jpg',
#  'image_4313.jpg',
#  'image_733.jpg',
#  'image_1494.jpg',
#  'image_4124.jpg',
#  'image_5358.jpg',
#  'image_4264.jpg',
#  'image_4703.jpg',
#  'image_2780.jpg',
#  'image_3903.jpg',
#  'image_7107.jpg',
#  'image_5817.jpg',
#  'image_6231.jpg',
#  'image_2286.jpg',
#  'image_6349.jpg',
#  'image_413.jpg',
#  'image_258.jpg',
#  'image_751.jpg',
#  'image_5310.jpg',
#  'image_6714.jpg',
#  'image_4800.jpg',
#  'image_3891.jpg',
#  'image_4465.jpg',
#  'image_5970.jpg',
#  'image_1077.jpg',
#  'image_4650.jpg',
#  'image_5213.jpg',
#  'image_5955.jpg',
#  'image_3177.jpg',
#  'image_6928.jpg',
#  'image_1811.jpg',
#  'image_6678.jpg',
#  'image_3881.jpg',
#  'image_2076.jpg',
#  'image_1267.jpg',
#  'image_6538.jpg',
#  'image_6514.jpg',
#  'image_2660.jpg',
#  'image_3463.jpg',
#  'image_5568.jpg',
#  'image_5862.jpg',
#  'image_2810.jpg',
#  'image_6569.jpg',
#  'image_4411.jpg',
#  'image_3815.jpg',
#  'image_4794.jpg',
#  'image_2611.jpg',
#  'image_2501.jpg',
#  'image_5626.jpg',
#  'image_268.jpg',
#  'image_2348.jpg',
#  'image_2636.jpg',
#  'image_1223.jpg',
#  'image_2618.jpg',
#  'image_2608.jpg',
#  'image_1639.jpg',
#  'image_2473.jpg',
#  'image_914.jpg',
#  'image_6787.jpg',
#  'image_2460.jpg',
#  'image_2323.jpg',
#  'image_379.jpg',
#  'image_6175.jpg',
#  'image_3745.jpg',
#  'image_5504.jpg',
#  'image_2002.jpg',
#  'image_1783.jpg',
#  '._image_352.jpg',
#  'image_4750.jpg',
#  'image_6664.jpg',
#  'image_1737.jpg',
#  'image_6374.jpg',
#  'image_431.jpg',
#  'image_915.jpg',
#  'image_2260.jpg',
#  'image_1974.jpg',
#  'image_4930.jpg',
#  'image_4093.jpg',
#  'image_1276.jpg',
#  'image_1619.jpg',
#  'image_6122.jpg',
#  'image_2492.jpg',
#  'image_4479.jpg',
#  'image_6816.jpg',
#  '._image_25.jpg',
#  'image_2366.jpg',
#  'image_2124.jpg',
#  'image_686.jpg',
#  'image_7124.jpg',
#  'image_4524.jpg',
#  'image_2521.jpg',
#  'image_6917.jpg',
#  'image_752.jpg',
#  'image_94.jpg',
#  'image_14.jpg',
#  'image_1328.jpg',
#  'image_1210.jpg',
#  'image_5405.jpg',
#  '._image_136.jpg',
#  'image_6710.jpg',
#  'image_2202.jpg',
#  'image_428.jpg',
#  'image_4477.jpg',
#  'image_2619.jpg',
#  'image_45.jpg',
#  'image_3604.jpg',
#  'image_3820.jpg',
#  'image_3251.jpg',
#  'image_6825.jpg',
#  'image_1056.jpg',
#  'image_5792.jpg',
#  'image_4442.jpg',
#  'image_1076.jpg',
#  '._image_425.jpg',
#  'image_635.jpg',
#  'image_1775.jpg',
#  'image_5273.jpg',
#  'image_1910.jpg',
#  'image_4122.jpg',
#  'image_4646.jpg',
#  'image_3392.jpg',
#  'image_4305.jpg',
#  'image_762.jpg',
#  'image_6730.jpg',
#  'image_1745.jpg',
#  'image_5451.jpg',
#  'image_1207.jpg',
#  'image_6266.jpg',
#  'image_33.jpg',
#  'image_3068.jpg',
#  'image_6525.jpg',
#  '._image_83.jpg',
#  'image_4309.jpg',
#  'image_119.jpg',
#  'image_1623.jpg',
#  'image_332.jpg',
#  'image_259.jpg',
#  'image_383.jpg',
#  'image_1428.jpg',
#  'image_3659.jpg',
#  'image_1099.jpg',
#  'image_6110.jpg',
#  'image_817.jpg',
#  'image_5139.jpg',
#  'image_670.jpg',
#  'image_3884.jpg',
#  'image_3599.jpg',
#  'image_5020.jpg',
#  '._image_379.jpg',
#  'image_3042.jpg',
#  'image_2090.jpg',
#  'image_3939.jpg',
#  'image_143.jpg',
#  '._image_14.jpg',
#  'image_5433.jpg',
#  'image_6788.jpg',
#  'image_1829.jpg',
#  'image_3314.jpg',
#  'image_4404.jpg',
#  'image_4010.jpg',
#  'image_5973.jpg',
#  'image_1225.jpg',
#  'image_4723.jpg',
#  'image_4259.jpg',
#  'image_3028.jpg',
#  'image_6642.jpg',
#  'image_6357.jpg',
#  'image_1444.jpg',
#  'image_4853.jpg',
#  'image_6202.jpg',
#  'image_5313.jpg',
#  'image_5239.jpg',
#  'image_2658.jpg',
#  'image_5964.jpg',
#  '._image_198.jpg',
#  'image_463.jpg',
#  'image_4882.jpg',
#  'image_5066.jpg',
#  'image_6853.jpg',
#  'image_3031.jpg',
#  'image_1201.jpg',
#  'image_47.jpg',
#  'image_6932.jpg',
#  'image_5974.jpg',
#  'image_3710.jpg',
#  '._image_301.jpg',
#  'image_1747.jpg',
#  'image_2302.jpg',
#  'image_3777.jpg',
#  'image_1430.jpg',
#  'image_3703.jpg',
#  'image_6997.jpg',
#  'image_2337.jpg',
#  'image_6489.jpg',
#  'image_1411.jpg',
#  'image_1120.jpg',
#  'image_2975.jpg',
#  'image_2836.jpg',
#  'image_4263.jpg',
#  'image_660.jpg',
#  'image_5197.jpg',
#  'image_5099.jpg',
#  'image_2735.jpg',
#  'image_1938.jpg',
#  'image_3690.jpg',
#  'image_37.jpg',
#  'image_1851.jpg',
#  'image_5421.jpg',
#  'image_579.jpg',
#  'image_16.jpg',
#  '._image_26.jpg',
#  'image_1190.jpg',
#  'image_5330.jpg',
#  'image_1006.jpg',
#  'image_3184.jpg',
#  'image_6711.jpg',
#  '._image_220.jpg',
#  '._image_79.jpg',
#  'image_1176.jpg',
#  'image_1374.jpg',
#  'image_4834.jpg',
#  'image_330.jpg',
#  'image_2282.jpg',
#  'image_4876.jpg',
#  'image_1456.jpg',
#  'image_3660.jpg',
#  'image_1342.jpg',
#  'image_810.jpg',
#  'image_5753.jpg',
#  'image_1510.jpg',
#  'image_727.jpg',
#  'image_2289.jpg',
#  'image_6772.jpg',
#  'image_4152.jpg',
#  'image_2916.jpg',
#  'image_4683.jpg',
#  'image_5922.jpg',
#  'image_5875.jpg',
#  'image_3739.jpg',
#  'image_1931.jpg',
#  'image_1600.jpg',
#  'image_5601.jpg',
#  'image_4772.jpg',
#  '._image_274.jpg',
#  'image_6176.jpg',
#  'image_4300.jpg',
#  'image_4243.jpg',
#  'image_3072.jpg',
#  'image_5009.jpg',
#  'image_3240.jpg',
#  'image_313.jpg',
#  'image_583.jpg',
#  'image_1027.jpg',
#  'image_2852.jpg',
#  'image_4237.jpg',
#  'image_5658.jpg',
#  'image_2324.jpg',
#  'image_5131.jpg',
#  'image_3284.jpg',
#  'image_6636.jpg',
#  'image_3760.jpg',
#  'image_4527.jpg',
#  'image_7126.jpg',
#  'image_5063.jpg',
#  'image_2729.jpg',
#  'image_5328.jpg',
#  'image_3073.jpg',
#  'image_3337.jpg',
#  'image_6201.jpg',
#  'image_4713.jpg',
#  'image_322.jpg',
#  'image_6665.jpg',
#  'image_3552.jpg',
#  'image_6052.jpg',
#  'image_136.jpg',
#  'image_3435.jpg',
#  'image_5044.jpg',
#  'image_4417.jpg',
#  'image_1375.jpg',
#  'image_4074.jpg',
#  'image_4549.jpg',
#  'image_389.jpg',
#  'image_2855.jpg',
#  'image_182.jpg',
#  'image_5649.jpg',
#  '._image_416.jpg',
#  'image_4614.jpg',
#  'image_5237.jpg',
#  'image_1516.jpg',
#  'image_107.jpg',
#  'image_1457.jpg',
#  'image_5899.jpg',
#  '._image_164.jpg',
#  'image_883.jpg',
#  'image_5788.jpg',
#  'image_6848.jpg',
#  'image_3148.jpg',
#  'image_3099.jpg',
#  'image_2504.jpg',
#  'image_5967.jpg',
#  'image_4017.jpg',
#  'image_6893.jpg',
#  'image_3459.jpg',
#  'image_626.jpg',
#  'image_4383.jpg',
#  'image_7093.jpg',
#  'image_4171.jpg',
#  'image_5810.jpg',
#  'image_49.jpg',
#  'image_5016.jpg',
#  'image_405.jpg',
#  'image_4091.jpg',
#  'image_2144.jpg',
#  'image_5259.jpg',
#  'image_2602.jpg',
#  'image_6021.jpg',
#  'image_4060.jpg',
#  'image_5003.jpg',
#  'image_3285.jpg',
#  'image_4934.jpg',
#  '._image_333.jpg',
#  '._image_387.jpg',
#  'image_4329.jpg',
#  'image_1086.jpg',
#  'image_6505.jpg',
#  'image_1671.jpg',
#  'image_3664.jpg',
#  'image_935.jpg',
#  '._image_58.jpg',
#  '._image_117.jpg',
#  'image_1695.jpg',
#  'image_2328.jpg',
#  'image_4642.jpg',
#  'image_6548.jpg',
#  'image_3849.jpg',
#  'image_2781.jpg',
#  '._image_283.jpg',
#  'image_3276.jpg',
#  'image_5675.jpg',
#  'image_5022.jpg',
#  'image_1268.jpg',
#  'image_2808.jpg',
#  'image_961.jpg',
#  'image_4809.jpg',
#  'image_3185.jpg',
#  'image_2775.jpg',
#  'image_3818.jpg',
#  'image_5524.jpg',
#  'image_6172.jpg',
#  'image_3637.jpg',
#  'image_4431.jpg',
#  'image_3719.jpg',
#  'image_5682.jpg',
#  'image_5511.jpg',
#  'image_6343.jpg',
#  'image_4340.jpg',
#  'image_5041.jpg',
#  '._image_272.jpg',
#  'image_570.jpg',
#  'image_5011.jpg',
#  'image_2226.jpg',
#  'image_6567.jpg',
#  'image_500.jpg',
#  'image_5081.jpg',
#  'image_5657.jpg',
#  'image_3802.jpg',
#  'image_504.jpg',
#  'image_217.jpg',
#  'image_1079.jpg',
#  'image_2265.jpg',
#  'image_3409.jpg',
#  'image_5894.jpg',
#  'image_6995.jpg',
#  'image_5441.jpg',
#  'image_314.jpg',
#  'image_4872.jpg',
#  'image_6023.jpg',
#  'image_4415.jpg',
#  'image_1681.jpg',
#  'image_6043.jpg',
#  'image_4881.jpg',
#  'image_4562.jpg',
#  'image_3477.jpg',
#  'image_5653.jpg',
#  'image_4399.jpg',
#  'image_1759.jpg',
#  'image_5054.jpg',
#  'image_1439.jpg',
#  'image_4494.jpg',
#  'image_1341.jpg',
#  'image_6633.jpg',
#  'image_3142.jpg',
#  'image_2019.jpg',
#  '._image_124.jpg',
#  'image_3093.jpg',
#  'image_6903.jpg',
#  'image_6739.jpg',
#  '._image_324.jpg',
#  'image_1459.jpg',
#  '._image_99.jpg',
#  'image_5431.jpg',
#  'image_871.jpg',
#  'image_371.jpg',
#  'image_3427.jpg',
#  'image_1567.jpg',
#  'image_6508.jpg',
#  'image_4717.jpg',
#  'image_5889.jpg',
#  'image_608.jpg',
#  'image_5551.jpg',
#  'image_1778.jpg',
#  'image_6697.jpg',
#  'image_3233.jpg',
#  'image_1707.jpg',
#  'image_3715.jpg',
#  'image_3836.jpg',
#  'image_4241.jpg',
#  'image_4996.jpg',
#  'image_2060.jpg',
#  'image_3922.jpg',
#  'image_2509.jpg',
#  'image_2874.jpg',
#  'image_1929.jpg',
#  'image_3545.jpg',
#  'image_2229.jpg',
#  'image_2157.jpg',
#  'image_5662.jpg',
#  'image_5112.jpg',
#  'image_5288.jpg',
#  'image_2142.jpg',
#  'image_4291.jpg',
#  '._image_244.jpg',
#  'image_5348.jpg',
#  'image_3149.jpg',
#  'image_7095.jpg',
#  'image_2003.jpg',
#  'image_7020.jpg',
#  'image_2175.jpg',
#  'image_278.jpg',
#  'image_1875.jpg',
#  'image_3123.jpg',
#  'image_6102.jpg',
#  'image_3325.jpg',
#  'image_4055.jpg',
#  'image_3079.jpg',
#  'image_6377.jpg',
#  'image_1307.jpg',
#  'image_2305.jpg',
#  '._image_175.jpg',
#  'image_5681.jpg',
#  'image_6227.jpg',
#  'image_264.jpg',
#  'image_6482.jpg',
#  'image_277.jpg',
#  'image_2333.jpg',
#  'image_6992.jpg',
#  'image_1572.jpg',
#  'image_6427.jpg',
#  'image_5615.jpg',
#  'image_6330.jpg',
#  'image_285.jpg',
#  'image_3590.jpg',
#  'image_5111.jpg',
#  'image_2135.jpg',
#  'image_4865.jpg',
#  'image_3067.jpg',
#  'image_3607.jpg',
#  'image_6926.jpg',
#  'image_4671.jpg',
#  'image_402.jpg',
#  'image_3504.jpg',
#  'image_1399.jpg',
#  'image_5758.jpg',
#  'image_5476.jpg',
#  'image_5427.jpg',
#  'image_2876.jpg',
#  'image_3324.jpg',
#  'image_127.jpg',
#  'image_2140.jpg',
#  'image_1186.jpg',
#  'image_3791.jpg',
#  '._image_210.jpg',
#  'image_6974.jpg',
#  'image_3882.jpg',
#  '._image_139.jpg',
#  'image_4293.jpg',
#  'image_2938.jpg',
#  'image_765.jpg',
#  'image_3809.jpg',
#  'image_1369.jpg',
#  'image_453.jpg',
#  'image_1018.jpg',
#  'image_649.jpg',
#  'image_1129.jpg',
#  'image_631.jpg',
#  'image_6971.jpg',
#  'image_2456.jpg',
#  'image_5294.jpg',
#  'image_1098.jpg',
#  'image_5161.jpg',
#  'image_6036.jpg',
#  '._image_343.jpg',
#  'image_6914.jpg',
#  'image_2821.jpg',
#  'image_932.jpg',
#  'image_5387.jpg',
#  'image_343.jpg',
#  'image_2732.jpg',
#  'image_6600.jpg',
#  'image_6978.jpg',
#  'image_1714.jpg',
#  'image_384.jpg',
#  'image_2441.jpg',
#  'image_1011.jpg',
#  '._image_82.jpg',
#  'image_5242.jpg',
#  'image_2088.jpg',
#  'image_6138.jpg',
#  'image_6487.jpg',
#  'image_1313.jpg',
#  'image_6643.jpg',
#  'image_618.jpg',
#  'image_5572.jpg',
#  'image_7081.jpg',
#  'image_1722.jpg',
#  'image_5567.jpg',
#  'image_4539.jpg',
#  'image_4657.jpg',
#  'image_4297.jpg',
#  'image_602.jpg',
#  'image_7131.jpg',
#  '._image_29.jpg',
#  'image_1901.jpg',
#  'image_299.jpg',
#  'image_1264.jpg',
#  'image_2339.jpg',
#  'image_176.jpg',
#  'image_4449.jpg',
#  'image_1047.jpg',
#  'image_51.jpg',
#  'image_6803.jpg',
#  'image_6292.jpg',
#  'image_2896.jpg',
#  'image_6887.jpg',
#  'image_5837.jpg',
#  'image_3108.jpg',
#  'image_5752.jpg',
#  '._image_88.jpg',
#  'image_873.jpg',
#  'image_5507.jpg',
#  'image_5479.jpg',
#  'image_5267.jpg',
#  'image_4170.jpg',
#  'image_582.jpg',
#  'image_3966.jpg',
#  '._image_485.jpg',
#  'image_4283.jpg',
#  'image_785.jpg',
#  'image_3908.jpg',
#  'image_2.jpg',
#  'image_2951.jpg',
#  'image_7001.jpg',
#  'image_3704.jpg',
#  'image_786.jpg',
#  'image_3554.jpg',
#  'image_7137.jpg',
#  'image_3319.jpg',
#  'image_1075.jpg',
#  'image_326.jpg',
#  'image_1761.jpg',
#  'image_4099.jpg',
#  'image_5563.jpg',
#  'image_590.jpg',
#  'image_5911.jpg',
#  'image_1962.jpg',
#  'image_5258.jpg',
#  'image_6222.jpg',
#  'image_730.jpg',
#  'image_177.jpg',
#  'image_4086.jpg',
#  'image_1144.jpg',
#  'image_4843.jpg',
#  ...]

# %%
os.path.join(data_folder, os.listdir(data_folder)[num])
# Out:
# '/home/bartheq/Documents/playground/image_colorization/data/layout_images/._image_23.jpg'

# %%
fig, ax = plt.subplots(4, 3, figsize=(20,20))
images = []
for item, a in zip(range(12), ax.flatten()):
    num = np.random.randint(0, len(os.listdir(data_folder)))
    image_path = os.path.join(data_folder, os.listdir(data_folder)[num])
    while image_path[0] == '.':
        num = np.random.randint(0, len(os.listdir(data_folder)))
        image_path = os.path.join(data_folder, os.listdir(data_folder)[num])
    image = cv2.imread(os.path.join(data_folder, os.listdir(data_folder)[num]))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    a.imshow(image)
    images.append(image)

plt.show()

# %%
fig, ax = plt.subplots(4,3,figsize=(20,20))
for image, a in zip(images, ax.flatten()):
    image = cv2.cvtColor(image, cv2.COLOR_RGB2LUV)
    a.imshow(image)
    
plt.show()

# %%
fig, ax = plt.subplots(1,3,figsize=(20,20))
ax[0].imshow(image[..., 0])
ax[1].imshow(image[..., 1])
ax[2].imshow(image[..., 2])

# %%
fig, ax = plt.subplots(1,3,figsize=(20,20))
ax[0].hist(image[..., 0])
ax[1].hist(image[..., 1])
ax[2].hist(image[..., 2])
plt.show()

# %%
# images, Ls, Us, Vs = [], [], [], []
# files = os.listdir(data_folder)
# for item in range(len(files)):
#     image_path = os.path.join(data_folder, os.listdir(data_folder)[item])
#     while image_path[0] == '.':
#         num = np.random.randint(0, len(os.listdir(data_folder)))
#         image_path = os.path.join(data_folder, os.listdir(data_folder)[item])
#     image = cv2.imread(os.path.join(data_folder, os.listdir(data_folder)[num]))
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     images.append(image)
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2LUV)
#     Ls.append(image[..., 0])
#     Us.append(image[..., 1])
#     Vs.append(image[..., 2])
    
# np.save(os.path.join(save_directory, 'images.npy'), np.array(images))
# np.save(os.path.join(save_directory, 'Ls.npy'), np.array(Ls))
# np.save(os.path.join(save_directory, 'Us.npy'), np.array(Us))
# np.save(os.path.join(save_directory, 'Vs.npy'), np.array(Vs))

# %%
Vs[0]
# Out:
# array([[101, 101, 102, ..., 104, 106, 106],
#        [101, 100, 103, ..., 104, 104, 106],
#        [103, 103, 103, ..., 102, 102, 104],
#        ...,
#        [136, 136, 137, ..., 136, 136, 136],
#        [136, 136, 137, ..., 136, 136, 137],
#        [136, 136, 136, ..., 136, 137, 137]], dtype=uint8)
